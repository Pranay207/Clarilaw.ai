# %%
import pandas as pd

errors = X_test.copy()
errors["Actual"] = y_test
errors["Predicted"] = y_pred

wrong_predictions = errors[errors["Actual"] != errors["Predicted"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 errors = X_test.copy()
#       4 errors["Actual"] = y_test
#       5 errors["Predicted"] = y_pred
#
# NameError: name 'X_test' is not defined

# %%
wrong_predictions["Actual"].value_counts()
wrong_predictions["Predicted"].value_counts()
